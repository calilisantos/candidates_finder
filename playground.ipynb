# %% [markdown]
# # **Dependencies import**

# %%
from pyspark.sql import functions as F, SparkSession, types as T
import requests

# %% [markdown]
# # **Creating spark session**

# %%
spark = (
    SparkSession.builder
        .appName('candidates_finder')
            .master('local[*]')
                .getOrCreate()
)

# %% [markdown]
# # **Defining configs**

# %%
COLUMNS_LIST = [
    "name",
    "company",
    "blog",
    "email",
    "bio",
    "public_repos",
    "followers",
    "following",
    "created_at"
]
COMPANY_PATTERN_TO_REMOVE = "@"
CSV_FILE = "followers_info.csv"
DATE_COLUMN = "created_at"
DATE_FORMAT = "dd/MM/yyyy"
FOLLOWERS_URL = 'https://api.github.com/users/calilisantos/followers'
FOLLOWER_KEY = 'url'
token = "PAT git hub token here"
headers = {
    "Accept": "application/vnd.github.v3+json",
    "Authorization": f"Bearer {token}"
}
schema = T.StructType([
    T.StructField("name", T.StringType(), True),
    T.StructField("company", T.StringType(), True),
    T.StructField("blog", T.StringType(), True),
    T.StructField("email", T.StringType(), True),
    T.StructField("bio", T.StringType(), True),
    T.StructField("public_repos", T.IntegerType(), True),
    T.StructField("followers", T.IntegerType(), True),
    T.StructField("following", T.IntegerType(), True),
    T.StructField("created_at", T.StringType(), True)
])

# %% [markdown]
# # **Creating get_followers_info function**

# %%
def get_followers_info(followers_url):
    try:
        response = requests.get(followers_url, headers=headers)
        response.raise_for_status()
        return {column: response.json()[column] for column in COLUMNS_LIST}
    except Exception as e:
        print(f"Error: {e}")
        return {column: None for column in COLUMNS_LIST}

# %% [markdown]
# # **Getting followers info**

# %%
followers_url_response = requests.get(FOLLOWERS_URL, headers=headers)
followers_url_response_json = followers_url_response.json()


followers_lists = list(map( lambda follower: follower[FOLLOWER_KEY], followers_url_response_json))

followers_info = list(map(get_followers_info, followers_lists))
followers_info
# Out:
# [{'name': 'Christian Deacon',
#   'company': '@deaconn-net',
#   'blog': 'https://deaconn.net/',
#   'email': 'christianmdeacon@gmail.com',
#   'bio': 'Software/network engineer and developer with a love for open source!\r\n\r\n@modcommunity @bestmods @bestserversio @gamecomio ',
#   'public_repos': 144,
#   'followers': 23062,
#   'following': 81347,
#   'created_at': '2014-01-26T22:43:05Z'},
#  {'name': 'Levy Nunes',
#   'company': None,
#   'blog': 'https://www.linkedin.com/in/levyvix/',
#   'email': 'levy.vix@gmail.com',
#   'bio': 'Estatística - UFES',
#   'public_repos': 105,
#   'followers': 28,
#   'following': 65,
#   'created_at': '2014-10-30T22:52:20Z'},
#  {'name': 'Leandro Teixeira',
#   'company': None,
#   'blog': '',
#   'email': 'leandroteixeira3@gmail.com',
#   'bio': 'Software Developer passionate about Machine Learning and Python. \r\n',
#   'public_repos': 25,
#   'followers': 32,
#   'following': 50,
#   'created_at': '2014-11-10T11:48:31Z'},
#  {'name': "Fernando D'luccas",
#   'company': None,
#   'blog': '',
#   'email': 'fernandodluccas@gmail.com',
#   'bio': None,
#   'public_repos': 67,
#   'followers': 28,
#   'following': 40,
#   'created_at': '2015-04-07T23:04:23Z'},
#  {'name': 'Alp ฿📈🚀🌕',
#   'company': None,
#   'blog': '',
#   'email': None,
#   'bio': '🗽 Be greedy when others are fearful and be fearful when others are greedy ☕️ Full-Stack 🖥💻📱⌚️ Finance, Crypto ⛓ (Blockchain, Smart contracts etc.)',
#   'public_repos': 61,
#   'followers': 25703,
#   'following': 284505,
#   'created_at': '2016-03-31T09:16:13Z'},
#  {'name': 'Lucas',
#   'company': 'XP Inc',
#   'blog': 'https://www.linkedin.com/in/defreitas-lucas',
#   'email': 'lucas.dfa@live.com',
#   'bio': 'Mineiro formado em Sistemas de Informação pela Newton Paiva - Desenvolvedor Júnior atuando na XP Inc.\r\n',
#   'public_repos': 25,
#   'followers': 56,
#   'following': 48,
#   'created_at': '2016-04-29T22:56:36Z'},
#  {'name': 'Wellington Rodrigues',
#   'company': 'XP Inc.',
#   'blog': 'https://www.linkedin.com/in/wellingtonrodrigues/',
#   'email': 'ton.rodrigues@icloud.com',
#   'bio': 'Back-end at XP Inc. | Software Engineer I',
#   'public_repos': 43,
#   'followers': 151,
#   'following': 172,
#   'created_at': '2017-07-30T23:48:20Z'},
#  {'name': 'Genivaldo',
#   'company': 'Trybe',
#   'blog': '',
#   'email': 'genivaldo.serra@live.com',
#   'bio': 'DevOps Engineer | Desenvolvedor Web',
#   'public_repos': 19,
#   'followers': 61,
#   'following': 107,
#   'created_at': '2018-06-03T22:55:31Z'},
#  {'name': 'Jorge Zupirolli',
#   'company': None,
#   'blog': '',
#   'email': 'jorgebertolo@gmail.com',
#   'bio': None,
#   'public_repos': 52,
#   'followers': 58,
#   'following': 57,
#   'created_at': '2018-08-16T13:09:06Z'},
#  {'name': 'Angélica Silva',
#   'company': None,
#   'blog': '',
#   'email': None,
#   'bio': 'Estudante de Desenvolvimento Web na Trybe.',
#   'public_repos': 16,
#   'followers': 45,
#   'following': 30,
#   'created_at': '2019-06-02T22:50:26Z'},
#  {'name': 'PROENÇA, Marco',
#   'company': None,
#   'blog': '',
#   'email': None,
#   'bio': None,
#   'public_repos': 26,
#   'followers': 35,
#   'following': 74,
#   'created_at': '2019-08-21T00:33:13Z'},
#  {'name': 'Bárbara Queiroz',
#   'company': None,
#   'blog': 'https://www.linkedin.com/in/barbaraqueirozsoares/',
#   'email': 'barbaraqs@gmail.com',
#   'bio': 'Mineira formada em Engenharia de Energia pela UFSC e agora Desenvolvedora Full-Stack na XP Inc',
#   'public_repos': 6,
#   'followers': 93,
#   'following': 156,
#   'created_at': '2020-04-13T21:07:16Z'},
#  {'name': 'Mariane Algayer',
#   'company': 'XP Inc.',
#   'blog': '',
#   'email': None,
#   'bio': 'Software Engineer',
#   'public_repos': 8,
#   'followers': 74,
#   'following': 86,
#   'created_at': '2020-06-04T20:09:55Z'},
#  {'name': 'Klecianny Melo',
#   'company': 'Br24',
#   'blog': 'https://www.linkedin.com/in/kecbm/',
#   'email': 'kleciannymelo@gmail.com',
#   'bio': '💻 Software Engineer | 🎓 Food Engineer',
#   'public_repos': 57,
#   'followers': 210,
#   'following': 144,
#   'created_at': '2020-06-24T19:58:49Z'},
#  {'name': 'Fellipe Horta Parreiras',
#   'company': None,
#   'blog': 'https://www.linkedin.com/in/fellipeparreiras',
#   'email': 'fhparreiras@gmail.com',
#   'bio': 'Desenvolvedor Fullstack Júnior ',
#   'public_repos': 17,
#   'followers': 41,
#   'following': 70,
#   'created_at': '2020-08-17T17:52:41Z'},
#  {'name': 'Rafhael Oliveira',
#   'company': '@tryber',
#   'blog': 'https://underewarrr.github.io/',
#   'email': 'rafhaelxd@gmail.com',
#   'bio': 'Engenheiro De Software | Desenvolvedor Full Stack |\r\n',
#   'public_repos': 57,
#   'followers': 110,
#   'following': 130,
#   'created_at': '2020-11-10T05:09:57Z'},
#  {'name': 'Rhenan Stocco Zimmermann',
#   'company': 'Full Stack Developer',
#   'blog': 'https://www.linkedin.com/in/rhenanstoccozimmermann/',
#   'email': 'r.stoccozimmermann@gmail.com',
#   'bio': None,
#   'public_repos': 11,
#   'followers': 39,
#   'following': 78,
#   'created_at': '2021-04-13T00:33:27Z'},
#  {'name': 'Weslley A. Santos',
#   'company': '@GRUPO-XP',
#   'blog': 'https://www.linkedin.com/in/weslley-almerindo/',
#   'email': 'weslleyalmerindo2@gmail.com',
#   'bio': 'Software Engineer at XP Inc.',
#   'public_repos': 22,
#   'followers': 35,
#   'following': 34,
#   'created_at': '2021-04-29T22:30:04Z'},
#  {'name': 'Rafael Pereira',
#   'company': None,
#   'blog': 'rafaelratier@hotmail.com',
#   'email': None,
#   'bio': None,
#   'public_repos': 16,
#   'followers': 36,
#   'following': 132,
#   'created_at': '2021-05-17T03:11:17Z'},
#  {'name': 'Gabriel Nery',
#   'company': None,
#   'blog': 'https://gabrielnerys.github.io/',
#   'email': 'gabe.nery@live.com',
#   'bio': 'Software Engineer',
#   'public_repos': 16,
#   'followers': 72,
#   'following': 73,
#   'created_at': '2021-05-31T04:08:29Z'},
#  {'name': 'alexandre-andre',
#   'company': None,
#   'blog': '',
#   'email': None,
#   'bio': 'Estudante desenvolvimento web - full stack\r\n',
#   'public_repos': 22,
#   'followers': 44,
#   'following': 69,
#   'created_at': '2021-06-10T20:29:16Z'},
#  {'name': 'Patrick Bastos',
#   'company': None,
#   'blog': '',
#   'email': 'patrickbastosc@gmail.com',
#   'bio': "I'm Oliver's dad, backend software engineer and that's all, because that's all i can do in 24 hours. 😮\u200d💨",
#   'public_repos': 18,
#   'followers': 35,
#   'following': 44,
#   'created_at': '2021-06-19T11:30:12Z'},
#  {'name': 'Elimar ',
#   'company': 'working at XP Inc',
#   'blog': 'https://www.linkedin.com/in/elimar-lucena-de-oliveira/',
#   'email': None,
#   'bio': 'Back-end Development.',
#   'public_repos': 4,
#   'followers': 62,
#   'following': 48,
#   'created_at': '2021-07-01T17:26:05Z'},
#  {'name': 'Gisely K Cavalli',
#   'company': '@grupo-xp',
#   'blog': 'https://www.linkedin.com/in/giselycavalli/',
#   'email': None,
#   'bio': 'Software Engineer at XP Inc.',
#   'public_repos': 15,
#   'followers': 78,
#   'following': 96,
#   'created_at': '2021-07-20T17:55:48Z'},
#  {'name': 'Ingrid Ramos',
#   'company': None,
#   'blog': 'https://www.linkedin.com/in/ingridrcs/',
#   'email': None,
#   'bio': 'Estudante de Desenvolvimento Web Full Stack na Trybe',
#   'public_repos': 26,
#   'followers': 39,
#   'following': 61,
#   'created_at': '2021-08-15T18:04:57Z'},
#  {'name': 'Byanca Knorst',
#   'company': 'XP Inc.',
#   'blog': 'https://www.linkedin.com/in/byancaknorst/',
#   'email': 'byancaknorst@gmail.com',
#   'bio': 'Estudante de desenvolvimento Web em Trybe.',
#   'public_repos': 6,
#   'followers': 83,
#   'following': 91,
#   'created_at': '2021-08-16T19:58:40Z'},
#  {'name': 'Julia Lana Patto',
#   'company': 'Software Engineer at @grupo-xp',
#   'blog': 'https://www.linkedin.com/in/julialanapatto/',
#   'email': 'julialanapatto@gmail.com',
#   'bio': 'Desenvolvedora Back-End Jr.',
#   'public_repos': 12,
#   'followers': 85,
#   'following': 109,
#   'created_at': '2021-09-03T15:00:35Z'},
#  {'name': 'Edmur Neves',
#   'company': None,
#   'blog': 'https://edmurneves.github.io/',
#   'email': 'edmurneves@gmail.com',
#   'bio': 'Nerd por natureza, apaixonado por tecnologia. Estou aqui para  aprender e compartilhar conhecimentos em Tecnologia.',
#   'public_repos': 19,
#   'followers': 43,
#   'following': 62,
#   'created_at': '2021-09-03T21:18:15Z'},
#  {'name': 'Suelen Arruda',
#   'company': '@grupo-xp',
#   'blog': 'https://www.linkedin.com/in/suelen-arruda/',
#   'email': 'suelenonyrius@gmail.com',
#   'bio': 'Software engineer I \r\nat XP inc. 🎨 ⬅️ 🧘🏽➡️  💻\r\n',
#   'public_repos': 26,
#   'followers': 153,
#   'following': 166,
#   'created_at': '2021-09-12T11:37:41Z'},
#  {'name': 'Rafael Perdigão',
#   'company': 'Tania Bulhões',
#   'blog': 'https://rafaelpermec.github.io',
#   'email': 'dev.rafaelpermec@gmail.com',
#   'bio': 'Javascript / Typescript Fullstack Software Developer',
#   'public_repos': 12,
#   'followers': 101,
#   'following': 101,
#   'created_at': '2021-09-16T13:24:14Z'}]

# %% [markdown]
# # **Creating dataframe**

# %%
data = spark.createDataFrame(followers_info, schema=schema)
data.show()
# Out:
# +--------------------+--------------------+--------------------+--------------------+--------------------+------------+---------+---------+--------------------+
# |                name|             company|                blog|               email|                 bio|public_repos|followers|following|          created_at|
# +--------------------+--------------------+--------------------+--------------------+--------------------+------------+---------+---------+--------------------+
# |    Christian Deacon|        @deaconn-net|https://deaconn.net/|christianmdeacon@...|Software/network ...|         144|    23062|    81347|2014-01-26T22:43:05Z|
# |          Levy Nunes|                NULL|https://www.linke...|  levy.vix@gmail.com|  Estatística - UFES|         105|       28|       65|2014-10-30T22:52:20Z|
# |    Leandro Teixeira|                NULL|                    |leandroteixeira3@...|Software Develope...|          25|       32|       50|2014-11-10T11:48:31Z|
# |   Fernando D'luccas|                NULL|                    |fernandodluccas@g...|                NULL|          67|       28|       40|2015-04-07T23:04:23Z|
# |         Alp ฿📈🚀🌕|                NULL|                    |                NULL|🗽 Be greedy when...|          61|    25703|   284505|2016-03-31T09:16:13Z|
# |               Lucas|              XP Inc|https://www.linke...|  lucas.dfa@live.com|Mineiro formado e...|          25|       56|       48|2016-04-29T22:56:36Z|
# |Wellington Rodrigues|             XP Inc.|https://www.linke...|ton.rodrigues@icl...|Back-end at XP In...|          43|      151|      172|2017-07-30T23:48:20Z|
# |           Genivaldo|               Trybe|                    |genivaldo.serra@l...|DevOps Engineer |...|          19|       61|      107|2018-06-03T22:55:31Z|
# |     Jorge Zupirolli|                NULL|                    |jorgebertolo@gmai...|                NULL|          52|       58|       57|2018-08-16T13:09:06Z|
# |      Angélica Silva|                NULL|                    |                NULL|Estudante de Dese...|          16|       45|       30|2019-06-02T22:50:26Z|
# |      PROENÇA, Marco|                NULL|                    |                NULL|                NULL|          26|       35|       74|2019-08-21T00:33:13Z|
# |     Bárbara Queiroz|                NULL|https://www.linke...| barbaraqs@gmail.com|Mineira formada e...|           6|       93|      156|2020-04-13T21:07:16Z|
# |     Mariane Algayer|             XP Inc.|                    |                NULL|   Software Engineer|           8|       74|       86|2020-06-04T20:09:55Z|
# |      Klecianny Melo|                Br24|https://www.linke...|kleciannymelo@gma...|💻 Software Engin...|          57|      210|      144|2020-06-24T19:58:49Z|
# |Fellipe Horta Par...|                NULL|https://www.linke...|fhparreiras@gmail...|Desenvolvedor Ful...|          17|       41|       70|2020-08-17T17:52:41Z|
# |    Rafhael Oliveira|             @tryber|https://underewar...| rafhaelxd@gmail.com|Engenheiro De Sof...|          57|      110|      130|2020-11-10T05:09:57Z|
# |Rhenan Stocco Zim...|Full Stack Developer|https://www.linke...|r.stoccozimmerman...|                NULL|          11|       39|       78|2021-04-13T00:33:27Z|
# |   Weslley A. Santos|           @GRUPO-XP|https://www.linke...|weslleyalmerindo2...|Software Engineer...|          22|       35|       34|2021-04-29T22:30:04Z|
# |      Rafael Pereira|                NULL|rafaelratier@hotm...|                NULL|                NULL|          16|       36|      132|2021-05-17T03:11:17Z|
# |        Gabriel Nery|                NULL|https://gabrielne...|  gabe.nery@live.com|   Software Engineer|          16|       72|       73|2021-05-31T04:08:29Z|
# +--------------------+--------------------+--------------------+--------------------+--------------------+------------+---------+---------+--------------------+
# only showing top 20 rows

# %% [markdown]
# # **Transforming company column**

# %%
data = data.withColumn(
    "company",
    F.regexp_replace(
        F.col("company"),
        COMPANY_PATTERN_TO_REMOVE,
        ""
    )
)

data.show()
# Out:
# +--------------------+--------------------+--------------------+--------------------+--------------------+------------+---------+---------+--------------------+
# |                name|             company|                blog|               email|                 bio|public_repos|followers|following|          created_at|
# +--------------------+--------------------+--------------------+--------------------+--------------------+------------+---------+---------+--------------------+
# |    Christian Deacon|         deaconn-net|https://deaconn.net/|christianmdeacon@...|Software/network ...|         144|    23062|    81347|2014-01-26T22:43:05Z|
# |          Levy Nunes|                NULL|https://www.linke...|  levy.vix@gmail.com|  Estatística - UFES|         105|       28|       65|2014-10-30T22:52:20Z|
# |    Leandro Teixeira|                NULL|                    |leandroteixeira3@...|Software Develope...|          25|       32|       50|2014-11-10T11:48:31Z|
# |   Fernando D'luccas|                NULL|                    |fernandodluccas@g...|                NULL|          67|       28|       40|2015-04-07T23:04:23Z|
# |         Alp ฿📈🚀🌕|                NULL|                    |                NULL|🗽 Be greedy when...|          61|    25703|   284505|2016-03-31T09:16:13Z|
# |               Lucas|              XP Inc|https://www.linke...|  lucas.dfa@live.com|Mineiro formado e...|          25|       56|       48|2016-04-29T22:56:36Z|
# |Wellington Rodrigues|             XP Inc.|https://www.linke...|ton.rodrigues@icl...|Back-end at XP In...|          43|      151|      172|2017-07-30T23:48:20Z|
# |           Genivaldo|               Trybe|                    |genivaldo.serra@l...|DevOps Engineer |...|          19|       61|      107|2018-06-03T22:55:31Z|
# |     Jorge Zupirolli|                NULL|                    |jorgebertolo@gmai...|                NULL|          52|       58|       57|2018-08-16T13:09:06Z|
# |      Angélica Silva|                NULL|                    |                NULL|Estudante de Dese...|          16|       45|       30|2019-06-02T22:50:26Z|
# |      PROENÇA, Marco|                NULL|                    |                NULL|                NULL|          26|       35|       74|2019-08-21T00:33:13Z|
# |     Bárbara Queiroz|                NULL|https://www.linke...| barbaraqs@gmail.com|Mineira formada e...|           6|       93|      156|2020-04-13T21:07:16Z|
# |     Mariane Algayer|             XP Inc.|                    |                NULL|   Software Engineer|           8|       74|       86|2020-06-04T20:09:55Z|
# |      Klecianny Melo|                Br24|https://www.linke...|kleciannymelo@gma...|💻 Software Engin...|          57|      210|      144|2020-06-24T19:58:49Z|
# |Fellipe Horta Par...|                NULL|https://www.linke...|fhparreiras@gmail...|Desenvolvedor Ful...|          17|       41|       70|2020-08-17T17:52:41Z|
# |    Rafhael Oliveira|              tryber|https://underewar...| rafhaelxd@gmail.com|Engenheiro De Sof...|          57|      110|      130|2020-11-10T05:09:57Z|
# |Rhenan Stocco Zim...|Full Stack Developer|https://www.linke...|r.stoccozimmerman...|                NULL|          11|       39|       78|2021-04-13T00:33:27Z|
# |   Weslley A. Santos|            GRUPO-XP|https://www.linke...|weslleyalmerindo2...|Software Engineer...|          22|       35|       34|2021-04-29T22:30:04Z|
# |      Rafael Pereira|                NULL|rafaelratier@hotm...|                NULL|                NULL|          16|       36|      132|2021-05-17T03:11:17Z|
# |        Gabriel Nery|                NULL|https://gabrielne...|  gabe.nery@live.com|   Software Engineer|          16|       72|       73|2021-05-31T04:08:29Z|
# +--------------------+--------------------+--------------------+--------------------+--------------------+------------+---------+---------+--------------------+
# only showing top 20 rows

# %% [markdown]
# # **Transforming created_at column**

# %%
data = data.withColumn(
    DATE_COLUMN,
    F.date_format(
        F.col(DATE_COLUMN),
        DATE_FORMAT
    )
)

data.show()
# Out:
# +--------------------+--------------------+--------------------+--------------------+--------------------+------------+---------+---------+----------+
# |                name|             company|                blog|               email|                 bio|public_repos|followers|following|created_at|
# +--------------------+--------------------+--------------------+--------------------+--------------------+------------+---------+---------+----------+
# |    Christian Deacon|         deaconn-net|https://deaconn.net/|christianmdeacon@...|Software/network ...|         144|    23062|    81347|26/01/2014|
# |          Levy Nunes|                NULL|https://www.linke...|  levy.vix@gmail.com|  Estatística - UFES|         105|       28|       65|30/10/2014|
# |    Leandro Teixeira|                NULL|                    |leandroteixeira3@...|Software Develope...|          25|       32|       50|10/11/2014|
# |   Fernando D'luccas|                NULL|                    |fernandodluccas@g...|                NULL|          67|       28|       40|07/04/2015|
# |         Alp ฿📈🚀🌕|                NULL|                    |                NULL|🗽 Be greedy when...|          61|    25703|   284505|31/03/2016|
# |               Lucas|              XP Inc|https://www.linke...|  lucas.dfa@live.com|Mineiro formado e...|          25|       56|       48|29/04/2016|
# |Wellington Rodrigues|             XP Inc.|https://www.linke...|ton.rodrigues@icl...|Back-end at XP In...|          43|      151|      172|30/07/2017|
# |           Genivaldo|               Trybe|                    |genivaldo.serra@l...|DevOps Engineer |...|          19|       61|      107|03/06/2018|
# |     Jorge Zupirolli|                NULL|                    |jorgebertolo@gmai...|                NULL|          52|       58|       57|16/08/2018|
# |      Angélica Silva|                NULL|                    |                NULL|Estudante de Dese...|          16|       45|       30|02/06/2019|
# |      PROENÇA, Marco|                NULL|                    |                NULL|                NULL|          26|       35|       74|20/08/2019|
# |     Bárbara Queiroz|                NULL|https://www.linke...| barbaraqs@gmail.com|Mineira formada e...|           6|       93|      156|13/04/2020|
# |     Mariane Algayer|             XP Inc.|                    |                NULL|   Software Engineer|           8|       74|       86|04/06/2020|
# |      Klecianny Melo|                Br24|https://www.linke...|kleciannymelo@gma...|💻 Software Engin...|          57|      210|      144|24/06/2020|
# |Fellipe Horta Par...|                NULL|https://www.linke...|fhparreiras@gmail...|Desenvolvedor Ful...|          17|       41|       70|17/08/2020|
# |    Rafhael Oliveira|              tryber|https://underewar...| rafhaelxd@gmail.com|Engenheiro De Sof...|          57|      110|      130|10/11/2020|
# |Rhenan Stocco Zim...|Full Stack Developer|https://www.linke...|r.stoccozimmerman...|                NULL|          11|       39|       78|12/04/2021|
# |   Weslley A. Santos|            GRUPO-XP|https://www.linke...|weslleyalmerindo2...|Software Engineer...|          22|       35|       34|29/04/2021|
# |      Rafael Pereira|                NULL|rafaelratier@hotm...|                NULL|                NULL|          16|       36|      132|17/05/2021|
# |        Gabriel Nery|                NULL|https://gabrielne...|  gabe.nery@live.com|   Software Engineer|          16|       72|       73|31/05/2021|
# +--------------------+--------------------+--------------------+--------------------+--------------------+------------+---------+---------+----------+
# only showing top 20 rows

# %% [markdown]
# # **Saving data to csv**

# %%
data.toPandas().to_csv(CSV_FILE, index=False)
